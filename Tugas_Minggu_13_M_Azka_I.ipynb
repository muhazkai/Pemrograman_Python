# %% [markdown]
# <a href="https://colab.research.google.com/github/muhazkai/Pemrograman_Python/blob/main/Tugas_Minggu_13_M_Azka_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
urban = []
suburban = []
open = []

# %%
for i in range(1, 202):
  i = i * 2.5
  x = 200 + i - 2.5
  plKiri = cos(1800, "urban", 80, 1.5, x)
  urban.append(plKiri)

# %%
for i in range(1, 202):
  i = i * 2.5
  x = 200 + i - 2.5
  plKiri = cos(1800, "suburban", 80, 1.5, x)
  suburban.append(plKiri)

# %%
for i in range(1, 202):
  i = i * 2.5
  x = 200 + i - 2.5
  plKiri = cos(1800, "open", 80, 1.5, x)
  open.append(plKiri)

# %%
freq1 = []
freq2 = []
freq3 = []

# %%
for i in range(1, 202):
  i = i * 2.5
  x = 200 + i - 2.5
  plKanan = cos(700, "urban", 80, 1.5, x)
  freq1.append(plKanan)

# %%
for i in range(1, 202):
  i = i * 2.5
  x = 200 + i - 2.5
  plKanan = cos(900, "urban", 80, 1.5, x)
  freq2.append(plKanan)

# %%
for i in range(1, 202):
  i = i * 2.5
  x = 200 + i - 2.5
  plKanan = cos(1800, "urban", 80, 1.5, x)
  freq3.append(plKanan)

# %%
x = []
for i in range(1, 202):
  i = i * 2.5
  x.append(200 + i - 2.5)
print(x)
# Out:
# [200.0, 202.5, 205.0, 207.5, 210.0, 212.5, 215.0, 217.5, 220.0, 222.5, 225.0, 227.5, 230.0, 232.5, 235.0, 237.5, 240.0, 242.5, 245.0, 247.5, 250.0, 252.5, 255.0, 257.5, 260.0, 262.5, 265.0, 267.5, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 382.5, 385.0, 387.5, 390.0, 392.5, 395.0, 397.5, 400.0, 402.5, 405.0, 407.5, 410.0, 412.5, 415.0, 417.5, 420.0, 422.5, 425.0, 427.5, 430.0, 432.5, 435.0, 437.5, 440.0, 442.5, 445.0, 447.5, 450.0, 452.5, 455.0, 457.5, 460.0, 462.5, 465.0, 467.5, 470.0, 472.5, 475.0, 477.5, 480.0, 482.5, 485.0, 487.5, 490.0, 492.5, 495.0, 497.5, 500.0, 502.5, 505.0, 507.5, 510.0, 512.5, 515.0, 517.5, 520.0, 522.5, 525.0, 527.5, 530.0, 532.5, 535.0, 537.5, 540.0, 542.5, 545.0, 547.5, 550.0, 552.5, 555
# ...

# %%
plt.figure()
plt.plot(x, urban, label="Urban")
plt.plot(x, suburban, label="Sub urban")
plt.plot(x, open, label="Open")
plt.legend()
plt.title('Kurva Tugas 13')
plt.xlabel('Jarak (Meter)')
plt.ylabel('Pathlodd (dB)')
plt.show()

plt.figure()
plt.plot(x, freq1, label="700 Mhz")
plt.plot(x, freq2, label="900 MHz")
plt.plot(x, freq3, label="1800 MHz")
plt.legend()
plt.title('Kurva Tugas 13')
plt.xlabel('Jarak (Meter)')
plt.ylabel('Pathlodd (dB)')
plt.show()
